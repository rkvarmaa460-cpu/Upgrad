# %%
a1="hello"
a2=" World"
print(a1+a2)
# Out:
# hello World

# %%
a=int(input("Enter the 1st no:"))
b=int(input("Enter the 2nd no:"))
Add=a+b
print("Addition:",Add)
Sub=a-b
print("Substraction:",Sub)
Mul=a*b
print("Multiplication:",Mul)
Div=a/b
print("Division:",Div)
# Out:
# Enter the 1st no: 5
# Enter the 2nd no: 4
# Addition: 9
# Substraction: 1
# Multiplication: 20
# Division: 1.25

# %%
first=input("Enter the first Name:")
sec=input("Enter the second Name:")

print(f"Hello,{first +" " +sec}! Welcome to Python program")
# Out:
# Enter the first Name: Joe
# Enter the second Name: Doe
# Hello,Joe Doe! Welcome to Python program
